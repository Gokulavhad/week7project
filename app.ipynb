# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import pickle

# Load the sample data
df = pd.read_csv("sample_data.csv")

# Use only 3 features
X = df[["Age", "Salary", "Education_Level"]]
y = df["Target"]

# Train the model
model = RandomForestClassifier()
model.fit(X, y)

# Save the new model
pickle.dump(model, open("model.pkl", "wb"))

# %%
import streamlit as st
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

# Load trained model
model = pickle.load(open("model.pkl", "rb"))

st.title("ML Model Deployment App")
st.write("Input your data to get predictions")

# Input fields
age = st.slider("Age", 18, 100, 25)
salary = st.number_input("Monthly Salary", 1000, 100000, 30000)
education = st.selectbox("Education Level", ["High School", "Bachelor's", "Master's", "PhD"])

# Map categorical inputs if needed
edu_map = {"High School": 0, "Bachelor's": 1, "Master's": 2, "PhD": 3}
input_data = pd.DataFrame([[age, salary, edu_map[education]]], columns=["Age", "Salary", "Education_Level"])

# Predict
if st.button("Predict"):
    prediction = model.predict(input_data)
    st.success(f"Prediction: {prediction[0]}")

# Visualizations (optional with sample data)
if st.checkbox("Show Sample Data & Visualization"):
    data = pd.read_csv("sample_data.csv")
    st.dataframe(data.head())

    st.subheader("Feature Correlation Heatmap")
    fig, ax = plt.subplots()
    sns.heatmap(data.corr(), annot=True, ax=ax)
    st.pyplot(fig)
# Out:
# 2025-07-04 15:30:45.135 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.824
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\ProgramData\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-07-04 15:30:46.825 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.833 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.842 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.844 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.846 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.849 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.851 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.853 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.861 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.864 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.866 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.870 Session state does not function when running a script without `streamlit run`
# 2025-07-04 15:30:46.876 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.886 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.890 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.894 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.897 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.899 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.909 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.911 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.913 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.916 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-04 15:30:46.947 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
